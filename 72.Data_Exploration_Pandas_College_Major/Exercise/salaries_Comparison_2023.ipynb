# %%
import pandas as pd
df = pd.read_csv('sample_data/output.csv')
df.head()
# Out:
#    Rank                                         Major     Degree  \
# 0     1                         Petroleum Engineering  Bachelors
# 1     2  Operations Research & Industrial Engineering  Bachelors
# 2     3                            Interaction Design  Bachelors
# 3     4              Applied Economics and Management  Bachelors
# 4     5                              Building Science  Bachelors
#
#    Early Career Pay(in $)  Mid-Career Pay(in $) % High Meaning
# 0                   97500                212500            61%
# 1                   98300                191800            21%
# 2                   74700                173600            54%
# 3                   76500                164400            54%
# 4                   69000                163100            47%

# %%
df.shape
# Out:
# (774, 6)

# %%
df.columns
# Out:
# Index(['Rank', 'Major', 'Degree', 'Early Career Pay(in $)',
#        'Mid-Career Pay(in $)', '% High Meaning'],
#       dtype='object')

# %%
clean_df = df.dropna()

# %%
clean_df['Early Career Pay(in $)'].idxmax()
# Out:
# 56

# %%
clean_df['Major'][56]
# Out:
# 'Physician Assistant Studies'

# %%
clean_df.sort_values('Early Career Pay(in $)', ascending=False).head()
# Out:
#      Rank                                         Major     Degree  \
# 56     56                   Physician Assistant Studies  Bachelors
# 1       2  Operations Research & Industrial Engineering  Bachelors
# 0       1                         Petroleum Engineering  Bachelors
# 117   117          Nuclear Engineering Technology (NET)  Bachelors
# 6       6                           Operations Research  Bachelors
#
#      Early Career Pay(in $)  Mid-Career Pay(in $) % High Meaning
# 56                   109600                136500            83%
# 1                     98300                191800            21%
# 0                     97500                212500            61%
# 117                   92500                122800            54%
# 6                     92200                160000            57%

# %%
clean_df.sort_values('Mid-Career Pay(in $)', ascending=False).head()
# Out:
#    Rank                                         Major     Degree  \
# 0     1                         Petroleum Engineering  Bachelors
# 1     2  Operations Research & Industrial Engineering  Bachelors
# 2     3                            Interaction Design  Bachelors
# 3     4              Applied Economics and Management  Bachelors
# 4     5                              Building Science  Bachelors
#
#    Early Career Pay(in $)  Mid-Career Pay(in $) % High Meaning
# 0                   97500                212500            61%
# 1                   98300                191800            21%
# 2                   74700                173600            54%
# 3                   76500                164400            54%
# 4                   69000                163100            47%

# %%
clean_df
# Out:
#      Rank                                         Major     Degree  \
# 0       1                         Petroleum Engineering  Bachelors
# 1       2  Operations Research & Industrial Engineering  Bachelors
# 2       3                            Interaction Design  Bachelors
# 3       4              Applied Economics and Management  Bachelors
# 4       5                              Building Science  Bachelors
# ..    ...                                           ...        ...
# 793   795                                Equine Studies  Bachelors
# 794   796                         Addictions Counseling  Bachelors
# 795   797                      Nonprofit Administration  Bachelors
# 796   798                     Early Childhood Education  Bachelors
# 797   799                                 Metalsmithing  Bachelors
#
#      Early Career Pay(in $)  Mid-Career Pay(in $) % High Meaning
# 0                     97500                212500            61%
# ...
